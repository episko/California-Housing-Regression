# %% [markdown]
# # Regression
# ## Machine Learning

# %% [markdown]
# ### This notebook presents some tests on Regression, including Linear Regression, Ridge Regression, Neural Networks for Regression.
# ### The dataset used in this example is the California Housing Prices, which can be dowloaded from [Kaggle](https://www.kaggle.com/camnugent/california-housing-prices).

# %% [markdown]
# #### This notebook uses Python version 3.6 or newer.

# %% [markdown]
# Let's start by installing the necessary libraries and toolkits.

# %%
import sys

if int(sys.version[0]) < 3 or int(sys.version[2]) < 6:
    assert("Python version 3.6 or newer is required")
else:
    # !conda install --yes --prefix {sys.prefix} matplotlib pandas scikit-learn seaborn tensorflow
#     !{sys.executable} -m pip install --upgrade matplotlib pandas scikit-learn seaborn tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %% [markdown]
# We continue by importing the necessary libraries and toolkits.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn.utils import shuffle
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD


# %matplotlib inline

# %% [markdown]
# Let's load the dataset into a Pandas Dataframe and take perform some data exploration.

# %%
df = pd.read_csv('./housing.csv', sep=',')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Let's check the column types, to make sure the dataset was properly loaded.

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# Let's check the number records in this dataset.

# %%
df.shape[0]
# Out:
# 20640

# %% [markdown]
# Now, let's check for NULL values

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# We can see that 207 out of 20640 records contain NULL values for the number of bedrooms in the house. <br/>
# This comprises about 1% of the data.

# %% [markdown]
# The first problem we have to solve is deciding what to do with the NULL values.<br/>
# Should we drop the records with such values or should we replace them with some other value, like the mean value (or the highest/lowest/median etc.)?

# %% [markdown]
# In this example, we are going to drop these records, since they are too few to affect the outcome.

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# Let's take a better look on our data, after preprocessing.

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %% [markdown]
# Let's see a histogram of the Media House Values.

# %%
plt.figure(figsize=(10,6))
sns.histplot(df, x='median_house_value', kde=True)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# Let's see how the location affects the Median House Value.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='longitude',y='latitude',data=df,hue='median_house_value')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Let's see the correlation between the data attributes.

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now, we should change the data type of Ocean Proximity from Object to a numeric value, to make sure we only have numeric values for the regression.

# %% [markdown]
# First of all, we should change the column type from Object to Categorical.

# %%
df.ocean_proximity = pd.Categorical(df.ocean_proximity)
df.dtypes
# Out:
# longitude              float64
# latitude               float64
# housing_median_age     float64
# total_rooms            float64
# total_bedrooms         float64
# population             float64
# households             float64
# median_income          float64
# median_house_value     float64
# ocean_proximity       category
# dtype: object

# %% [markdown]
# Now, we should replace textual categories with numerical categories.

# %%
df['ocean_proximity_num'] = df.ocean_proximity.cat.codes
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    ocean_proximity_num
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %% [markdown]
# Let's check the column types, to make sure the dataset was properly modified.

# %%
df.dtypes
# Out:
# longitude               float64
# latitude                float64
# housing_median_age      float64
# total_rooms             float64
# total_bedrooms          float64
# population              float64
# households              float64
# median_income           float64
# median_house_value      float64
# ocean_proximity        category
# ocean_proximity_num        int8
# dtype: object

# %% [markdown]
# What should we do with the geographic coordinates?<br/>
# The simplest approach is converting geolocation data into zones, using some clustering technique.

# %%
kmeans = KMeans(n_clusters=10, random_state=0)
kmeans.fit(df[['longitude','latitude']])
# Out:
# KMeans(n_clusters=10, random_state=0)

# %% [markdown]
# Let's integrate the lables into our dataframe.

# %%
df['area'] = kmeans.labels_
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    ocean_proximity_num  area
# 0                    3     7
# 1                    3     7
# 2                    3     7
# 3                    3     7
# 4                    3     7

# %% [markdown]
# Now, we have finalized all the data preprocessing and we can proceed with the regression.

# %% [markdown]
# The next problem we need to solve is deciding on the features we are going to use to train the regressor.

# %% [markdown]
# We can safely discard the textual Ocean Proximity feature, since we have the numerical one.<br/>
# We can also discard the Longitude and Latitude features, since we have engineered the labels.<br/>

# %% [markdown]
# Now, we should separate the the features from the target

# %%
y = df['median_house_value']
X = df.drop(['longitude','latitude','median_house_value','ocean_proximity'], axis = 1)

# %% [markdown]
# Let's split the data into training and validation sets. We keep 80% of the data for training and 20% for validation.<br/>
# These exact sets are going to be used for all 3 kinds of Gradient Descend for Ridge Regression.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)
print(f"Number of training points: {X_train.shape[0]}")
print(f"Number of validation points: {X_valid.shape[0]}")
# Out:
# Number of training points: 16346
# Number of validation points: 4087

# %% [markdown]
# Since we are going to perform regression we need to standardize and/or normalize our data, to improve the regression's accuracy.<br/>

# %% [markdown]
# In our example, we are going to perform Ridge Regression, which is a form of Linear Regression, we should scale our data.

# %%
xscaler = StandardScaler()
yscaler = StandardScaler()

X_train = xscaler.fit_transform(X_train.values)
X_valid = xscaler.transform(X_valid.values)
y_train = yscaler.fit_transform(y_train.values.reshape(-1, 1))
y_valid = yscaler.transform(y_valid.values.reshape(-1, 1))

# %% [markdown]
# Now we are going to proceed to the Ridge Regression through (mini-)batch Gradient Descend.

# %% [markdown]
# The Ridge Regression is performed using the following cost function:<br/>
#
# $J(\textbf{w}) = COST_\mathbf{w}(\mathbf{X},\mathbf{y})+\alpha \sum_{i=1}^m w_i^2 \\
# \hspace{1cm} = COST_\mathbf{w}(\mathbf{X},\mathbf{y})+\alpha (\mathbf{w}^\top \mathbf{w})$
#
# In the cost function above, $COST_\mathbf{w}(\mathbf{X},\mathbf{y})$ can be any of the following 3 distinct cost functions:
# * Residual sum of squares (**RSS**)
# * Mean squared error (**MSE**)
# * Root mean squared error (**RMSE**)

# %% [markdown]
# Let's perform a recap on the mathematics behind these 3 cost functions.
#
# * $RSS = \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i)^2$
# * $MSE = \frac{1}{m} \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i)^2$
# * $RMSE = \sqrt{\frac{1}{m} \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i)^2}$
#
# where $h_\mathbf{w}(\mathbf{x}_i)=\mathbf{w}^\top \mathbf{x}_i$

# %% [markdown]
# Now, let's see what the gradients of these 3 cost functions are.
# * $\frac{\partial}{\partial w_j} RSS = 2 \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i) x_{ij} \\
# \implies \nabla_\mathbf{w} RSS = 2 \mathbf{X}^\top(\mathbf{Xw}-\mathbf{y})$
#
# * $\frac{\partial}{\partial w_j} MSE = \frac{2}{m} \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i) x_{ij} = \frac{1}{m} \frac{\partial}{\partial w_j} RSS \\
# \implies \nabla_\mathbf{w} MSE = \frac{2}{m} \mathbf{X}^\top(\mathbf{Xw}-\mathbf{y})$
#
# * $\frac{\partial}{\partial w_j} RMSE = \
# \frac{1}{2} \frac{1}{\sqrt{\frac{1}{m} \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i)^2}} \frac{2}{m} \sum_{i=1}^m (h_\mathbf{w}(\mathbf{x}_i)-y_i) x_{ij} \
# = \frac{1}{2} \frac{1}{\sqrt{MSE}} \frac{\partial}{\partial w_j} MSE \\
# \implies \nabla_\mathbf{w} RMSE = \frac{1}{2} \frac{1}{\sqrt{MSE}} \nabla_\mathbf{w} MSE$

# %% [markdown]
# Let's define a custom class which helps with performing (mini-)batch Gradient Descend for Ridge Regression.<br/>
# This class is implemented so that we can keep a record of the cost for both for training and validation sets, for as many epochs as we have decided.<br/>

# %%
class BatchRidgeRegressor:
    def __init__(self, batch_size=None, alpha=0.0001, epochs=1000, learning_rate=0.01, cost='mse'):
        self.__batch_size=batch_size # 
        self.__alpha=alpha
        self.__epochs=epochs
        self.__learning_rate=learning_rate
        self.__weights=None
        
        if cost == 'rss':
            self.__cost = self.__rss
            self.__gradient = self.__rss_grad
        elif cost == 'mse':
            self.__cost = self.__mse
            self.__gradient = self.__mse_grad
        elif cost == 'rmse':
            self.__cost = self.__rmse
            self.__gradient = self.__rmse_grad
    
    def fit(self, X_train, X_valid, y_train, y_valid):
        # Add a column of ones to X for the bias term
        X_train = np.c_[ X_train, np.ones(X_train.shape[0]) ]
        X_valid = np.c_[ X_valid, np.ones(X_valid.shape[0]) ]
        
        # Make sure the shape of y is correct by
        # reshaping it into a (n,1) vector, if needed.
        if len(y_train.shape) == 1:
            y_train = y_train.reshape(-1, 1)
        if len(y_valid.shape) == 1:
            y_valid = y_valid.reshape(-1, 1)
        
        # Create inital weights w0, w1, ..., wn with zero values
        w = np.zeros((X_train.shape[1],1))
        
        # Initialize cost lists (both trainings and validation),
        # useful for plotting changes
        train_costs = []
        valid_costs = []
        
        if not self.__batch_size:
            # Full batch
            for epoch in range(self.__epochs):
                # Update weights
                w -= self.__learning_rate * self.__gradient(X_train, y_train, w)
                
                # Useful for plotting loss progress
                train_cost = round(self.__cost(X_train, y_train, w), 5)
                valid_cost = round(self.__cost(X_valid, y_valid, w), 5)
                train_costs.append(train_cost)
                valid_costs.append(valid_cost)
                
        else:
            # Specific batch size
            for epoch in range(self.__epochs):
                # Shuffle training set
                X_train, y_train = shuffle(X_train, y_train)
                
                # Randomly choose batch indexes
                sample_ids = np.random.randint(0, X_train.shape[0]-self.__batch_size+1, 
                                               int(X_train.shape[0]/self.__batch_size))
                # Iterate over batches
                for i in sample_ids:
                    X = X_train[i:i+self.__batch_size]
                    y = y_train[i:i+self.__batch_size]
                    
                    # Update weights
                    w -= self.__learning_rate * self.__gradient(X, y, w)
                
                # Useful for plotting loss progress
                train_cost = round(self.__cost(X_train, y_train, w), 5)
                valid_cost = round(self.__cost(X_valid, y_valid, w), 5)
                train_costs.append(train_cost)
                valid_costs.append(valid_cost)
            
            # Store lastly updated parameter vector
            self.__weights = w
        
        return train_costs, valid_costs
    
    # Function to compute ridge RSS
    def __rss(self, X, y, w):
        #Initialization
        h = X @ w
        
        # Gradient Descend for Ridge Regression loss/cost computation
        J = ((h - y).T @ (h - y)) + self.__alpha * (w.T @ w)
        
        return J[0][0]
    
    # Function to compute ridge MSE
    def __mse(self, X, y, w):
        #Initialization
        m = X.shape[0]
        h = X @ w
        
        # Gradient Descend for Ridge Regression loss/cost computation
        J = (1.0 / m) * ((h - y).T @ (h - y)) + self.__alpha * (w.T @ w)
        
        return J[0][0]
    
    # Function to compute ridge RMSE
    def __rmse(self, X, y, w):
        #Initialization
        m = X.shape[0]
        h = X @ w
        
        # Gradient Descend for Ridge Regression loss/cost computation
        J = (1.0 / m) * (((h - y).T @ (h - y)) ** (1.0/2.0)) + self.__alpha * (w.T @ w)
        
        return J[0][0]
    
    # Function to compute gradient of RSS
    def __rss_grad(self, X, y, w):
        #Initialization
        h = X @ w
        
        # Gradient Descend for Ridge Regression gradient computation
        grad = 2.0 * (X.T @ (h - y)) + 2.0 * self.__alpha * w
        
        return grad
    
    # Function to compute gradient of MSE 
    def __mse_grad(self, X, y, w):
        #Initialization
        m = X.shape[0]
        h = X @ w
        
        # Gradient Descend for Ridge Regression gradient computation
        grad = (2.0/m) * (X.T @ (h - y)) + 2.0 * self.__alpha * w
        
        return grad
    
    # Function to compute gradient of RMSE 
    def __rmse_grad(self, X, y, w):
        #Initialization
        m = X.shape[0]
        h = X @ w
        
        # Gradient Descend for Ridge Regression gradient computation
        grad = (1.0/2.0) * (self.__mse(X, y, w) ** (-1.0/2.0)) * self.__mse_grad(X, y, w) + 2.0 * self.__alpha * w
        
        return grad
    
    # Function to compute predictions created for the current dataset
    # where y = w0 + w1*x1 +...+wn*xn 
    def predict(self, X):
        pred = X @ self.__weights[:-1] + self.__weights[-1]
        
        return pred

# %% [markdown]
# Now we have to choose the total number of batches. We can do that by using different batch sizes.<br>
# The size of each batch is a fraction of the number of samples in our data. We can start from a small fraction and go up all the way to using all samples in a single batch.<br>
# This means that with the final mini-batch we actually perform (full) Batch Gradient Descend.<br/>

# %% [markdown]
# Here, we use 10 distinct batch sizes, which produces batch sizes that start from 0.1 of the number of samples in our data, then 0.2, 0.3 and so on until 1.0 (full-batch).

# %%
num_batch_sizes = 10
batch_sizes = [int((i/num_batch_sizes)*X_train.shape[0]) for i in range(1,num_batch_sizes+1)]

# %% [markdown]
# These are the parameters that we are going to use for simple Linear Regression.

# %%
# Linear Regression parameters
alpha=0
epochs=3000
learning_rate=0.01
cost='rmse'

# %% [markdown]
# Let's perform the regression and plot the costs.<br/>

# %%
x_axis = list(range(epochs))

for batch_size in batch_sizes:
    if batch_size != X_train.shape[0]:
        print("Performing Linear Regression with mini-batch " + 
              f"Gradient Descent and batch size {batch_size}")
        title = f"Linear Regression with mini-batch GD and batch size {batch_size}"
    else:
        print("Performing Linear Regression with mini-batch " + 
              f"Gradient Descent and batch size {batch_size} (full-batch)")
        title = "Linear Regression with (full-) batch GD"

    regressor = BatchRidgeRegressor(batch_size=batch_size, alpha=alpha, epochs=epochs, \
                                    learning_rate=learning_rate, cost=cost)

    train_losses, valid_losses = regressor.fit(X_train, X_valid, y_train, y_valid)

    y_pred = regressor.predict(X_valid)
    r2 = r2_score(y_valid, y_pred)
    print(f"R-squared score: {round(r2, 5)}")

    fig = plt.figure(figsize=(11, 7))
    plt.plot(x_axis, train_losses, label="Training", color='r', marker='+')
    plt.plot(x_axis, valid_losses, label="Validation", color='b')
    plt.title(title)
    plt.xlabel('epoch')
    plt.ylabel('RMSE')
    plt.xlim(0,epochs)
    plt.ylim(0,max(max(train_losses),max(valid_losses)))
    plt.legend(loc='best', fancybox=True, shadow=True)
    plt.grid(True)
    plt.show()

    print('-'*100)
    print('-'*100)
    print('')
# Out:
# Performing Linear Regression with mini-batch Gradient Descent and batch size 1634
# R-squared score: 0.60166
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 3269
# R-squared score: 0.60166
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 4903
# R-squared score: 0.60173
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 6538
# R-squared score: 0.60182
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 8173
# R-squared score: 0.60161
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 9807
# R-squared score: 0.6013
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 11442
# R-squared score: 0.60133
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 13076
# R-squared score: 0.60139
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 14711
# R-squared score: 0.60135
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Linear Regression with mini-batch Gradient Descent and batch size 16346 (full-batch)
# R-squared score: 0.60132
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# So, from the curves above we can see that our model neither overfits nor underfits the data, since both curvers have the same behavior.<br/>
# Moreover, the validation error is higher than the training error, as expected.<br/>
# The $R^2$ score is about 0.6, which is neither good or bad. Maybe we could have better results if we used some non-linear regression method.

# %% [markdown]
# Let's see if we can do better with Ridge Regression (very unlikely though).

# %% [markdown]
# These are the parameters that we are going to use for Ridge Regression.

# %%
# Ridge Regression parameters
alpha=0.0002
epochs=3000
learning_rate=0.01
cost='rmse'

# %% [markdown]
# Let's perform the regression and plot the costs.<br/>

# %%
x_axis = list(range(epochs))

for batch_size in batch_sizes:
    if batch_size != X_train.shape[0]:
        print("Performing Ridge Regression with mini-batch " + 
              f"Gradient Descent and batch size {batch_size}")
        title = f"Ridge Regression with mini-batch GD and batch size {batch_size}"
    else:
        print("Performing Ridge Regression with mini-batch " + 
              f"Gradient Descent and batch size {batch_size} (full-batch)")
        title = "Ridge Regression with (full-) batch GD"

    regressor = BatchRidgeRegressor(batch_size=batch_size, alpha=alpha, epochs=epochs, \
                                    learning_rate=learning_rate, cost=cost)

    train_losses, valid_losses = regressor.fit(X_train, X_valid, y_train, y_valid)

    y_pred = regressor.predict(X_valid)
    r2 = r2_score(y_valid, y_pred)
    print(f"R-squared score: {round(r2, 5)}")
    
    fig = plt.figure(figsize=(11, 7))
    plt.plot(x_axis, train_losses, label="Training", color='r', marker='+')
    plt.plot(x_axis, valid_losses, label="Validation", color='b')
    plt.title(title)
    plt.xlabel('epoch')
    plt.ylabel('RMSE')
    plt.xlim(0,epochs)
    plt.ylim(0,max(max(train_losses),max(valid_losses)))
    plt.legend(loc='best', fancybox=True, shadow=True)
    plt.grid(True)
    plt.show()

    print('-'*100)
    print('-'*100)
    print('')
# Out:
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 1634
# R-squared score: 0.60141
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 3269
# R-squared score: 0.60138
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 4903
# R-squared score: 0.60153
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 6538
# R-squared score: 0.60163
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 8173
# R-squared score: 0.60169
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 9807
# R-squared score: 0.60112
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 11442
# R-squared score: 0.60111
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 13076
# R-squared score: 0.60126
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 14711
# R-squared score: 0.60123
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Performing Ridge Regression with mini-batch Gradient Descent and batch size 16346 (full-batch)
# R-squared score: 0.60123
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# So, from the curves above and the $R^2$ score we can see that our model does not perform much differently than the previous one, as was expected.

# %% [markdown]
# Now we are going to proceed to the stochastic Gradient Descend for Ridge Regression.

# %% [markdown]
# To perform Ridge Regression through stochastic Gradient Descend we are going to use the SGDRegressor class from scikit-learn.<br/>
# From this class, we are going to perform the partial_fit method for training, so that we can keep a record of the RMSE for both for training and validation, for as many epochs as we have decided.

# %% [markdown]
# These are the parameters that we are going to use for the regression.

# %%
loss='squared_loss'
alpha=0.01
epochs=500
eta0=0.01
learning_rate='optimal'

# %% [markdown]
# Let's perform the regression and plot the costs.

# %%
# Function to compute ridge RMSE
def cost_function(X, y, w, alpha):
    #Initialization
    m = X.shape[0]
    h = X @ w
    
    # Gradient Descend for Ridge Regression loss/cost computation
    J = (1.0 / m) * (((h - y).T @ (h - y)) ** (1.0/2.0)) + alpha * (w.T @ w)

    return J[0][0]

# Add a column of ones to X for the bias term
X_train_reshaped = np.c_[ X_train, np.ones(X_train.shape[0]) ]
X_valid_reshaped = np.c_[ X_valid, np.ones(X_valid.shape[0]) ]

# Make sure the shape of y is correct by
# reshaping it into a (n,1) vector, if needed.
if len(y_train.shape) != 1:
    y_train_reshaped = y_train.reshape(-1)

regressor = SGDRegressor(loss=loss, alpha=alpha, eta0=eta0, \
                         learning_rate=learning_rate, warm_start=True, \
                         random_state=0)

# Initialize cost lists (both trainings and validation),
# useful for plotting changes
train_costs = []
valid_costs = []

# In every epoch, use partial fit to stochastic regression
# over the whole training set
for i in range(epochs):
    regressor.partial_fit(X_train_reshaped, y_train_reshaped)
    w = regressor.coef_.reshape(-1,1)

    # Add costs to lists
    train_cost = round(cost_function(X_train_reshaped, y_train, w, alpha), 5)
    valid_cost = round(cost_function(X_valid_reshaped, y_valid, w, alpha), 5)
    train_costs.append(train_cost)
    valid_costs.append(valid_cost)

r2 = regressor.score(X_valid_reshaped, y_valid)
print(f"R-squared score: {round(r2, 5)}")

x_axis = list(range(epochs))
fig = plt.figure(figsize=(11, 7))
plt.plot(x_axis, train_costs, label="Training", color='r', marker='+')
plt.plot(x_axis, valid_costs, label="Validation", color='b')
plt.title(f"Ridge Regression with stochastic GD")
plt.xlabel('epoch')
plt.ylabel('RMSE')
plt.xlim(0,epochs)
plt.ylim(0,max(max(train_costs),max(valid_costs)))
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# R-squared score: -2221129653771.693

# %% [markdown]
# The plot above does not give as a clear view of the behavior of the model, since it does not zoom close enough to see what is going on with the curves.<br/>
# So, we are going to perform an 100x zoom.

# %%
x_axis = list(range(epochs))
fig = plt.figure(figsize=(11, 7))
plt.plot(x_axis, train_costs, label="Training", color='r', marker='+')
plt.plot(x_axis, valid_costs, label="Validation", color='b')
plt.title(f"Ridge Regression with stochastic GD")
plt.xlabel('epoch')
plt.ylabel('RMSE')
plt.xlim(0,epochs)
plt.ylim(0,0.1*max(max(train_costs),max(valid_costs)))
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# So, from the curves above we can see that our model starts converging to the minimum RMSE after less than 300 iterations.<br/>
# We can also see that both the training and the validation curve go side-by-side, with minimum distance from each other (if any).<br/>
# Finally, the model neither overfits nor underfits the data, since both curvers have the same behavior.

# %% [markdown]
# However, the $R^2$ score is negative, which means we have a bad fit on our data.

# %% [markdown]
# Can we do better than the above using Neural Networks?

# %% [markdown]
# These are the parameters that we are going to use for Neural Regression.

# %%
dropout_rate=0.3
learning_rate=0.01
loss='mse'
metrics=[RootMeanSquaredError()]
monitor='val_loss'
mode='min'
patience=10
batch_size=128
epochs=500

# %% [markdown]
# Let's build a sequential fully-connected NN model and use Stochastic Gradient Descent as its optimizer.

# %%
model = Sequential()

model.add(Input(shape=X_train.shape[1], name="input"))
model.add(Dense(units=512, activation="relu", name="layer1"))
model.add(Dropout(rate=dropout_rate))
model.add(Dense(units=1024, activation="relu", name="layer2"))
model.add(Dropout(rate=dropout_rate))
model.add(Dense(units=512, activation="relu", name="layer3"))
model.add(Dropout(rate=dropout_rate))
model.add(Dense(units=1, name="output"))

optimizer = SGD(lr=learning_rate)

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

early_stop = EarlyStopping(monitor=monitor, mode=mode, verbose=1, patience=patience)

# %% [markdown]
# Let's train the model.

# %%
model.fit(x=X_train, y=y_train, 
          validation_data=(X_valid, y_valid), 
          batch_size=batch_size, epochs=epochs, 
          callbacks=[early_stop])
# Out:
# Epoch 1/500
# 128/128 [==============================] - 2s 14ms/step - loss: 0.6306 - root_mean_squared_error: 0.7941 - val_loss: 0.4104 - val_root_mean_squared_error: 0.6406
# Epoch 2/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.4292 - root_mean_squared_error: 0.6551 - val_loss: 0.3762 - val_root_mean_squared_error: 0.6134
# Epoch 3/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4066 - root_mean_squared_error: 0.6376 - val_loss: 0.3594 - val_root_mean_squared_error: 0.5995
# Epoch 4/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3919 - root_mean_squared_error: 0.6260 - val_loss: 0.3478 - val_root_mean_squared_error: 0.5898
# Epoch 5/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3818 - root_mean_squared_error: 0.6179 - val_loss: 0.3414 - val_root_mean_squared_error: 0.5843
# Epoch 6/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3698 - root_mean_squared_error: 0.6081 - val_loss: 0.3302 - val_root_mean_squared_error: 0.5746
# Epoch 7/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.3602 - root_mean_squared_error: 0.6002 - val_loss: 0.3267 - val_root_mean_squared_error: 0.5716
# Epoch 8/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.3565 - root_mean_squared_error: 0.5970 - val_loss: 0.3265 - val_root_mean_squared_error: 0.5714
# Epoch 9/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.3497 - root_mean_squared_error: 0.5914 - val_loss: 0.3186 - val_root_mean_squared_error: 0.5644
# Epoch 10/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3459 - root_mean_squared_error: 0.5881 - val_loss: 0.3149 - val_root_mean_squared_error: 0.5612
# Epoch 11/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3385 - root_mean_squared_error: 0.5818 - val_loss: 0.3102 - val_root_mean_squared_error: 0.5570
# Epoch 12/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3381 - root_mean_squared_error: 0.5815 - val_loss: 0.3052 - val_root_mean_squared_error: 0.5525
# Epoch 13/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.3301 - root_mean_squared_error: 0.5746 - val_loss: 0.3063 - val_root_mean_squared_error: 0.5534
# Epoch 14/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3297 - root_mean_squared_error: 0.5742 - val_loss: 0.2994 - val_root_mean_squared_error: 0.5472
# Epoch 15/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3259 - root_mean_squared_error: 0.5709 - val_loss: 0.2975 - val_root_mean_squared_error: 0.5454
# Epoch 16/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.3203 - root_mean_squared_error: 0.5660 - val_loss: 0.2970 - val_root_mean_squared_error: 0.5450
# Epoch 17/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3168 - root_mean_squared_error: 0.5628 - val_loss: 0.2962 - val_root_mean_squared_error: 0.5443
# Epoch 18/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3206 - root_mean_squared_error: 0.5662 - val_loss: 0.2946 - val_root_mean_squared_error: 0.5428
# Epoch 19/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.3166 - root_mean_squared_error: 0.5627 - val_loss: 0.2911 - val_root_mean_squared_error: 0.5396
# Epoch 20/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.3147 - root_mean_squared_error: 0.5610 - val_loss: 0.2903 - val_root_mean_squared_error: 0.5388
# Epoch 21/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3127 - root_mean_squared_error: 0.5592 - val_loss: 0.2909 - val_root_mean_squared_error: 0.5393
# Epoch 22/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - val_loss: 0.2852 - val_root_mean_squared_error: 0.5340
# Epoch 23/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.3086 - root_mean_squared_error: 0.5555 - val_loss: 0.2867 - val_root_mean_squared_error: 0.5354
# Epoch 24/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3063 - root_mean_squared_error: 0.5534 - val_loss: 0.2853 - val_root_mean_squared_error: 0.5341
# Epoch 25/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3026 - root_mean_squared_error: 0.5501 - val_loss: 0.2866 - val_root_mean_squared_error: 0.5354
# Epoch 26/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - val_loss: 0.2856 - val_root_mean_squared_error: 0.5344
# Epoch 27/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.3030 - root_mean_squared_error: 0.5505 - val_loss: 0.2800 - val_root_mean_squared_error: 0.5292
# Epoch 28/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.3000 - root_mean_squared_error: 0.5477 - val_loss: 0.2820 - val_root_mean_squared_error: 0.5311
# Epoch 29/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2986 - root_mean_squared_error: 0.5464 - val_loss: 0.2811 - val_root_mean_squared_error: 0.5302
# Epoch 30/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2976 - root_mean_squared_error: 0.5455 - val_loss: 0.2830 - val_root_mean_squared_error: 0.5320
# Epoch 31/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2957 - root_mean_squared_error: 0.5438 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299
# Epoch 32/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2938 - root_mean_squared_error: 0.5420 - val_loss: 0.2779 - val_root_mean_squared_error: 0.5271
# Epoch 33/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2941 - root_mean_squared_error: 0.5423 - val_loss: 0.2824 - val_root_mean_squared_error: 0.5314
# Epoch 34/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2922 - root_mean_squared_error: 0.5405 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299
# Epoch 35/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2922 - root_mean_squared_error: 0.5406 - val_loss: 0.2769 - val_root_mean_squared_error: 0.5262
# Epoch 36/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2915 - root_mean_squared_error: 0.5399 - val_loss: 0.2713 - val_root_mean_squared_error: 0.5209
# Epoch 37/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2914 - root_mean_squared_error: 0.5398 - val_loss: 0.2712 - val_root_mean_squared_error: 0.5208
# Epoch 38/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2888 - root_mean_squared_error: 0.5374 - val_loss: 0.2761 - val_root_mean_squared_error: 0.5255
# Epoch 39/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2858 - root_mean_squared_error: 0.5346 - val_loss: 0.2708 - val_root_mean_squared_error: 0.5204
# Epoch 40/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2864 - root_mean_squared_error: 0.5351 - val_loss: 0.2697 - val_root_mean_squared_error: 0.5193
# Epoch 41/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2861 - root_mean_squared_error: 0.5349 - val_loss: 0.2703 - val_root_mean_squared_error: 0.5199
# Epoch 42/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2840 - root_mean_squared_error: 0.5329 - val_loss: 0.2689 - val_root_mean_squared_error: 0.5186
# Epoch 43/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2840 - root_mean_squared_error: 0.5329 - val_loss: 0.2649 - val_root_mean_squared_error: 0.5147
# Epoch 44/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2830 - root_mean_squared_error: 0.5320 - val_loss: 0.2693 - val_root_mean_squared_error: 0.5189
# Epoch 45/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2825 - root_mean_squared_error: 0.5315 - val_loss: 0.2655 - val_root_mean_squared_error: 0.5152
# Epoch 46/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2804 - root_mean_squared_error: 0.5295 - val_loss: 0.2678 - val_root_mean_squared_error: 0.5175
# Epoch 47/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2820 - root_mean_squared_error: 0.5311 - val_loss: 0.2683 - val_root_mean_squared_error: 0.5180
# Epoch 48/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2822 - root_mean_squared_error: 0.5312 - val_loss: 0.2662 - val_root_mean_squared_error: 0.5159
# Epoch 49/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2782 - root_mean_squared_error: 0.5275 - val_loss: 0.2689 - val_root_mean_squared_error: 0.5185
# Epoch 50/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2772 - root_mean_squared_error: 0.5265 - val_loss: 0.2644 - val_root_mean_squared_error: 0.5142
# Epoch 51/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2781 - root_mean_squared_error: 0.5273 - val_loss: 0.2627 - val_root_mean_squared_error: 0.5126
# Epoch 52/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2787 - root_mean_squared_error: 0.5279 - val_loss: 0.2625 - val_root_mean_squared_error: 0.5123
# Epoch 53/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2780 - root_mean_squared_error: 0.5273 - val_loss: 0.2649 - val_root_mean_squared_error: 0.5147
# Epoch 54/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2764 - root_mean_squared_error: 0.5257 - val_loss: 0.2647 - val_root_mean_squared_error: 0.5145
# Epoch 55/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2754 - root_mean_squared_error: 0.5247 - val_loss: 0.2640 - val_root_mean_squared_error: 0.5138
# Epoch 56/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2755 - root_mean_squared_error: 0.5249 - val_loss: 0.2740 - val_root_mean_squared_error: 0.5235
# Epoch 57/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2761 - root_mean_squared_error: 0.5254 - val_loss: 0.2578 - val_root_mean_squared_error: 0.5077
# Epoch 58/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2749 - root_mean_squared_error: 0.5243 - val_loss: 0.2614 - val_root_mean_squared_error: 0.5113
# Epoch 59/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2736 - root_mean_squared_error: 0.5230 - val_loss: 0.2595 - val_root_mean_squared_error: 0.5094
# Epoch 60/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2726 - root_mean_squared_error: 0.5221 - val_loss: 0.2635 - val_root_mean_squared_error: 0.5133
# Epoch 61/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2725 - root_mean_squared_error: 0.5220 - val_loss: 0.2595 - val_root_mean_squared_error: 0.5094
# Epoch 62/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2716 - root_mean_squared_error: 0.5212 - val_loss: 0.2612 - val_root_mean_squared_error: 0.5111
# Epoch 63/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2715 - root_mean_squared_error: 0.5210 - val_loss: 0.2643 - val_root_mean_squared_error: 0.5141
# Epoch 64/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2708 - root_mean_squared_error: 0.5204 - val_loss: 0.2619 - val_root_mean_squared_error: 0.5117
# Epoch 65/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2731 - root_mean_squared_error: 0.5226 - val_loss: 0.2611 - val_root_mean_squared_error: 0.5110
# Epoch 66/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2709 - root_mean_squared_error: 0.5205 - val_loss: 0.2612 - val_root_mean_squared_error: 0.5110
# Epoch 67/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2730 - root_mean_squared_error: 0.5224 - val_loss: 0.2560 - val_root_mean_squared_error: 0.5060
# Epoch 68/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2706 - root_mean_squared_error: 0.5202 - val_loss: 0.2578 - val_root_mean_squared_error: 0.5077
# Epoch 69/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2703 - root_mean_squared_error: 0.5200 - val_loss: 0.2535 - val_root_mean_squared_error: 0.5035
# Epoch 70/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2696 - root_mean_squared_error: 0.5193 - val_loss: 0.2541 - val_root_mean_squared_error: 0.5041
# Epoch 71/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2692 - root_mean_squared_error: 0.5188 - val_loss: 0.2592 - val_root_mean_squared_error: 0.5091
# Epoch 72/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2696 - root_mean_squared_error: 0.5192 - val_loss: 0.2530 - val_root_mean_squared_error: 0.5029
# Epoch 73/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2696 - root_mean_squared_error: 0.5192 - val_loss: 0.2622 - val_root_mean_squared_error: 0.5120
# Epoch 74/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2669 - root_mean_squared_error: 0.5166 - val_loss: 0.2588 - val_root_mean_squared_error: 0.5087
# Epoch 75/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2669 - root_mean_squared_error: 0.5167 - val_loss: 0.2578 - val_root_mean_squared_error: 0.5077
# Epoch 76/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2661 - root_mean_squared_error: 0.5158 - val_loss: 0.2561 - val_root_mean_squared_error: 0.5061
# Epoch 77/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2659 - root_mean_squared_error: 0.5157 - val_loss: 0.2520 - val_root_mean_squared_error: 0.5020
# Epoch 78/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2659 - root_mean_squared_error: 0.5157 - val_loss: 0.2518 - val_root_mean_squared_error: 0.5018
# Epoch 79/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2638 - root_mean_squared_error: 0.5136 - val_loss: 0.2577 - val_root_mean_squared_error: 0.5077
# Epoch 80/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2683 - root_mean_squared_error: 0.5180 - val_loss: 0.2521 - val_root_mean_squared_error: 0.5021
# Epoch 81/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2660 - root_mean_squared_error: 0.5158 - val_loss: 0.2508 - val_root_mean_squared_error: 0.5008
# Epoch 82/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2663 - root_mean_squared_error: 0.5160 - val_loss: 0.2531 - val_root_mean_squared_error: 0.5030
# Epoch 83/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2623 - root_mean_squared_error: 0.5122 - val_loss: 0.2557 - val_root_mean_squared_error: 0.5057
# Epoch 84/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2648 - root_mean_squared_error: 0.5146 - val_loss: 0.2542 - val_root_mean_squared_error: 0.5042
# Epoch 85/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2622 - root_mean_squared_error: 0.5120 - val_loss: 0.2554 - val_root_mean_squared_error: 0.5054
# Epoch 86/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2625 - root_mean_squared_error: 0.5123 - val_loss: 0.2572 - val_root_mean_squared_error: 0.5071
# Epoch 87/500
# 128/128 [==============================] - 1s 11ms/step - loss: 0.2651 - root_mean_squared_error: 0.5148 - val_loss: 0.2509 - val_root_mean_squared_error: 0.5009
# Epoch 88/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2635 - root_mean_squared_error: 0.5133 - val_loss: 0.2526 - val_root_mean_squared_error: 0.5025
# Epoch 89/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2604 - root_mean_squared_error: 0.5103 - val_loss: 0.2545 - val_root_mean_squared_error: 0.5044
# Epoch 90/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2622 - root_mean_squared_error: 0.5120 - val_loss: 0.2518 - val_root_mean_squared_error: 0.5018
# Epoch 91/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2614 - root_mean_squared_error: 0.5113 - val_loss: 0.2491 - val_root_mean_squared_error: 0.4991
# Epoch 92/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2605 - root_mean_squared_error: 0.5104 - val_loss: 0.2545 - val_root_mean_squared_error: 0.5045
# Epoch 93/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2600 - root_mean_squared_error: 0.5099 - val_loss: 0.2513 - val_root_mean_squared_error: 0.5013
# Epoch 94/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2595 - root_mean_squared_error: 0.5094 - val_loss: 0.2473 - val_root_mean_squared_error: 0.4973
# Epoch 95/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2623 - root_mean_squared_error: 0.5122 - val_loss: 0.2488 - val_root_mean_squared_error: 0.4988
# Epoch 96/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2596 - root_mean_squared_error: 0.5095 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
# Epoch 97/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2582 - root_mean_squared_error: 0.5081 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
# Epoch 98/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2609 - root_mean_squared_error: 0.5108 - val_loss: 0.2572 - val_root_mean_squared_error: 0.5072
# Epoch 99/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2596 - root_mean_squared_error: 0.5095 - val_loss: 0.2478 - val_root_mean_squared_error: 0.4978
# Epoch 100/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2605 - root_mean_squared_error: 0.5104 - val_loss: 0.2470 - val_root_mean_squared_error: 0.4970
# Epoch 101/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2576 - root_mean_squared_error: 0.5075 - val_loss: 0.2437 - val_root_mean_squared_error: 0.4937
# Epoch 102/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2562 - root_mean_squared_error: 0.5062 - val_loss: 0.2490 - val_root_mean_squared_error: 0.4990
# Epoch 103/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2576 - root_mean_squared_error: 0.5075 - val_loss: 0.2492 - val_root_mean_squared_error: 0.4992
# Epoch 104/500
# 128/128 [==============================] - 2s 13ms/step - loss: 0.2577 - root_mean_squared_error: 0.5077 - val_loss: 0.2487 - val_root_mean_squared_error: 0.4987
# Epoch 105/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2597 - root_mean_squared_error: 0.5096 - val_loss: 0.2490 - val_root_mean_squared_error: 0.4990
# Epoch 106/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2569 - root_mean_squared_error: 0.5069 - val_loss: 0.2501 - val_root_mean_squared_error: 0.5001
# Epoch 107/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2558 - root_mean_squared_error: 0.5058 - val_loss: 0.2458 - val_root_mean_squared_error: 0.4957
# Epoch 108/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2579 - root_mean_squared_error: 0.5079 - val_loss: 0.2501 - val_root_mean_squared_error: 0.5001
# Epoch 109/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2576 - root_mean_squared_error: 0.5076 - val_loss: 0.2468 - val_root_mean_squared_error: 0.4968
# Epoch 110/500
# 128/128 [==============================] - 1s 12ms/step - loss: 0.2555 - root_mean_squared_error: 0.5054 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
# Epoch 111/500
# 128/128 [==============================] - 2s 12ms/step - loss: 0.2569 - root_mean_squared_error: 0.5069 - val_loss: 0.2468 - val_root_mean_squared_error: 0.4967
# Epoch 00111: early stopping

# %% [markdown]
# Let's plot the losses.

# %%
losses = pd.DataFrame(model.history.history)
losses.plot(figsize=(8,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let's evaluate our model.

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 128/128 [==============================] - 0s 2ms/step - loss: 0.2468 - root_mean_squared_error: 0.4967
# [0.24675412476062775, 0.4967435300350189]

# %%
y_pred = model.predict(X_valid)
r2 = r2_score(y_valid, y_pred)
print(f"R-squared score: {round(r2, 5)}")
# Out:
# R-squared score: 0.75475

# %% [markdown]
# It's obvious from the $R^2$ score that we get a better fit with the Neural Networks approach.<br/>
# However, the errors and the losses are significantly higher than those of the Linear Regression.
